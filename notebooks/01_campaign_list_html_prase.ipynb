# %% [markdown]
# # HTML Parsig : Get Text Data

# %%
import pandas as pd
from bs4 import BeautifulSoup

# %%
with open("C:/Users/ASUS/OneDrive/Desktop/Web Scraping/04_Campaigns-Scrape/data/Crowdfunders.html", "r", encoding="utf-8") as f:
    html = f.read()

# %%
html
# Out:
# '<!DOCTYPE html><html lang="en" dir="ltr"><head><link rel="stylesheet" href="/home/_next/static/chunks/7b8ba4fd16880d2f.css" data-precedence="next"><link rel="preload" as="script" fetchpriority="low" href="/home/_next/static/chunks/d18feffe58d34f72.js"><script src="/home/_next/static/chunks/02c79c13218a4da3.js" async=""></script><script src="/home/_next/static/chunks/04369e922b27723a.js" async=""></script><script src="/home/_next/static/chunks/7bd3a3d95a44e731.js" async=""></script><script src="/home/_next/static/chunks/turbopack-eef94b563eadc18c.js" async=""></script><script src="/home/_next/static/chunks/8f33ab591f267045.js" async=""></script><script src="/home/_next/static/chunks/7f357945c92c3074.js" async=""></script><script src="/home/_next/static/chunks/b6caf1a100b24e91.js" async=""></script><script src="/home/_next/static/chunks/ea2cb7b52ebf74bc.js" async=""></script><script src="/home/_next/static/chunks/fb6176e31a8669d6.js" async=""></script><script src="/home/_next/static/c
# ...

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all("div", class_="relative text-card-foreground bg-card border border-border/50 shadow-sm rounded-2xl h-full flex flex-col overflow-hidden hover:shadow-xl transition-all duration-300 hover:-translate-y-1 cursor-pointer")
# Out:
# [<div class="relative text-card-foreground bg-card border border-border/50 shadow-sm rounded-2xl h-full flex flex-col overflow-hidden hover:shadow-xl transition-all duration-300 hover:-translate-y-1 cursor-pointer"><div class="relative flex items-center justify-center overflow-hidden mt-3"><div class="relative aspect-square w-full max-w-[300px] overflow-hidden"><img alt="Torah Temimah" class="object-cover rounded-2xl" data-nimg="fill" decoding="async" loading="lazy" sizes="300px" src="/home/_next/image?url=https%3A%2F%2Fcdn.charityextra.com%2Fcampaign-assets%2Ftt%2Flogo-image-zdcn2.jpg&amp;w=3840&amp;q=75" srcset="/home/_next/image?url=https%3A%2F%2Fcdn.charityextra.com%2Fcampaign-assets%2Ftt%2Flogo-image-zdcn2.jpg&amp;w=32&amp;q=75 32w, /home/_next/image?url=https%3A%2F%2Fcdn.charityextra.com%2Fcampaign-assets%2Ftt%2Flogo-image-zdcn2.jpg&amp;w=48&amp;q=75 48w, /home/_next/image?url=https%3A%2F%2Fcdn.charityextra.com%2Fcampaign-assets%2Ftt%2Flogo-image-zdcn2.jpg&amp;w=64&amp;q=75 64w
# ...

# %%
len(soup.find_all("div", class_="relative text-card-foreground bg-card border border-border/50 shadow-sm rounded-2xl h-full flex flex-col overflow-hidden hover:shadow-xl transition-all duration-300 hover:-translate-y-1 cursor-pointer"))
# Out:
# 29

# %%
soup.find("div", class_="relative text-card-foreground bg-card border border-border/50 shadow-sm rounded-2xl h-full flex flex-col overflow-hidden hover:shadow-xl transition-all duration-300 hover:-translate-y-1 cursor-pointer")
# Out:
# 2

# %%
"body > div.min-h-screen.w-full.flex.flex-col > main > section.bg-background.mt-8.md\:mt-0.pb-16.md\:pb-24.\34 xl\:pb-28 > div > div.grid.grid-cols-1.md\:grid-cols-2.lg\:grid-cols-3.xl\:grid-cols-4.min-\[2000px\]\:grid-cols-4.gap-5.md\:gap-6.mx-auto.w-full.max-w-\[1400px\].transition-opacity.duration-200 > div:nth-child(3)"
